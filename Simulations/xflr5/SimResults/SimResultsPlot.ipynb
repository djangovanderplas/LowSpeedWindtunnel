# %%
import pandas as pd

# %%
df = pd.read_csv("LTT.csv", sep="\s+")
df
# Out:
#     alpha  Beta        CL       CDi       CDv        CD   CY   Cl        Cm  \
# 0    -3.0   0.0 -0.237649  0.003470  0.007129  0.010600  0.0  0.0  0.062421
# 1    -2.5   0.0 -0.197895  0.002453  0.007108  0.009561  0.0  0.0  0.052474
# 2    -2.0   0.0 -0.158849  0.001584  0.007066  0.008649  0.0  0.0  0.042548
# 3    -1.5   0.0 -0.119725  0.000904  0.007076  0.007979  0.0  0.0  0.032588
# 4    -1.0   0.0 -0.080541  0.000412  0.007044  0.007457  0.0  0.0  0.022594
# 5    -0.5   0.0 -0.041328  0.000111  0.007022  0.007133  0.0  0.0  0.012582
# 6     0.0   0.0 -0.002114  0.000001  0.007041  0.007042  0.0  0.0  0.002565
# 7     0.5   0.0  0.037070  0.000080  0.007028  0.007108  0.0 -0.0 -0.007423
# 8     1.0   0.0  0.076274  0.000350  0.007041  0.007390  0.0 -0.0 -0.017435
# 9     1.5   0.0  0.115469  0.000810  0.007064  0.007874  0.0 -0.0 -0.027440
# 10    2.0   0.0  0.154610  0.001459  0.007082  0.008541  0.0 -0.0 -0.037401
# ...

# %%
with pd.ExcelWriter('output1.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet_name_1')
