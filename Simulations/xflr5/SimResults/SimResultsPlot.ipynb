# %%
import pandas as pd

# %%
dfltt = pd.read_csv("LTT.csv", sep="\s+")
dfpanels = pd.read_csv("Panels.csv", sep="\s+")
dfVLM1 = pd.read_csv("VLM1.csv", sep="\s+")
dfVLM2 = pd.read_csv("VLM2.csv", sep="\s+")
dfVLM2
# Out:
#     alpha  Beta        CL       CDi       CDv        CD   CY   Cl        Cm  \
# 0    -3.0   0.0 -0.217185  0.002801  0.007123  0.009924  0.0  0.0  0.053841
# 1    -2.5   0.0 -0.181559  0.001957  0.007093  0.009051  0.0  0.0  0.045337
# 2    -2.0   0.0 -0.145900  0.001264  0.007065  0.008329 -0.0  0.0  0.036821
# 3    -1.5   0.0 -0.110213  0.000722  0.007076  0.007798 -0.0  0.0  0.028294
# 4    -1.0   0.0 -0.074506  0.000330  0.007040  0.007370 -0.0  0.0  0.019759
# 5    -0.5   0.0 -0.038785  0.000090  0.007025  0.007115 -0.0  0.0  0.011219
# 6     0.0   0.0 -0.003057  0.000001  0.007043  0.007044  0.0  0.0  0.002676
# 7     0.5   0.0  0.032671  0.000063  0.007031  0.007094  0.0 -0.0 -0.005868
# 8     1.0   0.0  0.068394  0.000277  0.007038  0.007315  0.0 -0.0 -0.014408
# 9     1.5   0.0  0.104103  0.000642  0.007060  0.007703  0.0 -0.0 -0.022944
# 10    2.0   0.0  0.139793  0.001159  0.007078  0.008237  0.0 -0.0 -0.031473
# ...
